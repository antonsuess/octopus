# %%
# !pip install paramiko
# Out:
# ...
#   Obtaining dependency information for paramiko from https://files.pythonhosted.org/packages/bb/8f/3cef65d3fe76e59f320405027d594a0332e44852fef722f0ee4e81e2e7e3/paramiko-3.3.1-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.4/473.4 kB 5.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for cryptography>=3.3 from https://files.pythonhosted.org/packages/0b/c1/2f1e8abb31ec0bf8b004052bbe0face0a8be386ed5ea30e5e300bfffd51a/cryptography-41.0.5-cp37-abi3-macosx_10_12_universal2.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.9/349.9 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 14.2 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import paramiko

ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())


ssh.connect('172.30.151.10', username='testsftp', password='FAEzE5JC7r98EYRq1uAu', timeout=5)
sftp = ssh.open_sftp()
print(sftp.listdir('/'))  # List root directory#
sftp.close()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /Users/anton.suess/projects/octopus/dataflow.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/Users/anton.suess/projects/octopus/dataflow.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> ssh = paramiko.SSHClient()
#       <a href='vscode-notebook-cell:/Users/anton.suess/projects/octopus/dataflow.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# ----> <a href='vscode-notebook-cell:/Users/anton.suess/projects/octopus/dataflow.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> ssh.connect('172.30.151.10', username='testsftp', password='FAEzE5JC7r98EYRq1uAu', timeout=5)
#       <a href='vscode-notebook-cell:/Users/anton.suess/projects/octopus/dataflow.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> sftp = ssh.open_sftp()
# ...

# %%
# Testing new connection details with and without appgate

import paramiko


ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())

try:
    ssh.connect('172.30.151.10', username='testsftp', password='FAEzE5JC7r98EYRq1uAu', timeout=5)
    sftp = ssh.open_sftp()
    print(sftp.listdir('/'))  # List root directory#
    sftp.close()
except Exception as e:
    print(f"Failed to connect: {e}")
finally:
    ssh.close()
# Out:
# []

# %%
from ftplib import FTP

# Testing OLD connection details with and without appgate

# specify your FTP server details
ftp_server =  '172.30.151.10'   #'217.68.22.220'
ftp_user = 'softp'
ftp_password = 'cTFmt7XN6e1GvxVu'

try:
    # establish the FTP connection
    ftp = FTP(ftp_server)
    ftp.login(user=ftp_user, passwd=ftp_password)

    # list the files in the root directory
    print(ftp.nlst())
    
    # close the connection
    ftp.quit()
except Exception as e:
    print(f"Failed to connect: {e}")
# Out:
# Failed to connect: 530 User cannot log in.

# %%
import paramiko
ssh = paramiko.SSHClient()
# ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())

try:
    ssh.connect('172.30.151.10', username='testsftp', password='FAEzE5JC7r98EYRq1uAu', timeout=5)
    sftp = ssh.open_sftp()
    print(sftp.listdir('/'))  # List root directory#
    sftp.close()
except Exception as e:
    print(f"Failed to connect: {e}")
finally:
    ssh.close()
# Out:
# Failed to connect: Server '172.30.151.10' not found in known_hosts

# %%
import paramiko

ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())

ssh.connect(hostname=, username=, password=, timeout=5)
sftp = ssh.open_sftp()
print(sftp.listdir('/'))
sftp.close()

# %%
zones
# Out:
# [{'id': 1,
#   'name': 'Sitting room',
#   'type': 'HEATING',
#   'dateCreated': '2021-12-07T15:21:17.666Z',
#   'deviceTypes': ['SU02', 'VA02'],
#   'devices': [{'deviceType': 'SU02',
#     'serialNo': 'SU0986656000',
#     'shortSerialNo': 'SU0986656000',
#     'currentFwVersion': '90.1',
#     'connectionState': {'value': True,
#      'timestamp': '2023-11-17T11:54:22.581Z'},
#     'characteristics': {'capabilities': ['INSIDE_TEMPERATURE_MEASUREMENT',
#       'IDENTIFY']},
#     'batteryState': 'LOW',
#     'duties': ['ZONE_UI', 'ZONE_LEADER']},
#    {'deviceType': 'VA02',
#     'serialNo': 'VA3661705984',
#     'shortSerialNo': 'VA3661705984',
#     'currentFwVersion': '95.1',
#     'connectionState': {'value': True,
#      'timestamp': '2023-11-17T11:51:11.297Z'},
#     'characteristics': {'capabilities': ['INSIDE_TEMPERATURE_MEASUREMENT',
#       'IDENTIFY']},
#     'mountingState': {'value': 'CALIBRATED',
#      'timestamp': '2023-09-02T03:01:59.095Z'},
# ...

# %%
responses = [{
      '_flags': 15,
      'st_size': 0,
      'st_uid': 0,
      'st_gid': 0,
      'st_mode': 33206,
      'st_atime': 1700675262,
      'st_mtime': 1700675262,
      'attr': {},
      'filename': 'STL01.PN056412.ARE',
      'longname': '-rw-rw-rw-    0 0        0               0 Nov 22 17:47 gas'
}]


data = []
for response in responses:
    data.append({
        "SizeInByte": response["st_size"],
        "ReceivedDate": (datetime.fromtimestamp(response["st_mtime"]).strftime("%Y-%m-%d %H:%M:%S %z")),
        "DataFlow": rf,
        "Gas_Elec": "Gas",
        "Received_FileName": response["filename"],
        "Status": None,
        "log_message": None
    })
    
print(data)
# Out:
# [{'SizeInByte': 0, 'ReceivedDate': '2023-11-22 17:47:42 ', 'DataFlow': 'ARE', 'Gas_Elec': 'Gas', 'Received_FileName': 'STL01.PN056412.ARE', 'Status': None, 'log_message': None}]

# %%
from datetime import datetime

timestamp = 1700675262
date = datetime.fromtimestamp(timestamp)
print(date)
print(date.strftime("%Y-%m-%d %H:%M:%S %z"))
# Out:
# 2023-11-22 17:47:42
# 2023-11-22 17:47:42
